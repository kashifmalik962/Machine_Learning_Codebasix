# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("data.csv")

# %%
data.head(60)
# Out:
#     match dayofweek        match_time       home_team       away_team  \
# 0       1       Sun  20-11-2022 19:00           Qatar         Ecuador
# 1       2       Mon  21-11-2022 16:00         England         IR Iran
# 2       3       Mon  21-11-2022 19:00         Senegal     Netherlands
# 3       4       Mon  21-11-2022 22:00   United States           Wales
# 4       5       Tue  22-11-2022 13:00       Argentina    Saudi Arabia
# 5       6       Tue  22-11-2022 16:00         Denmark         Tunisia
# 6       7       Tue  22-11-2022 19:00          Mexico          Poland
# 7       8       Tue  22-11-2022 22:00          France       Australia
# 8       9       Wed  23-11-2022 13:00         Morocco         Croatia
# 9      10       Wed  23-11-2022 16:00         Germany           Japan
# 10     11       Wed  23-11-2022 19:00           Spain      Costa Rica
# 11     12       Wed  23-11-2022 22:00         Belgium          Canada
# ...

# %%
sns.boxplot(data['age'])
# Out:
# <AxesSubplot: >

# %%
data.loc[(data['age']>=22) & (data['age']<=25),['age']].value_counts().sum()
# Out:
# 15

# %%
data['age'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data['age'].value_counts()
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Bar Chart

# %%
data['dayofweek'].value_counts()
# Out:
# Tue    11
# Fri    10
# Mon     9
# Wed     9
# Thu     8
# Sat     8
# Sun     7
# Name: dayofweek, dtype: int64

# %%
data['dayofweek'].value_counts()
# Out:
# Tue    11
# Fri    10
# Mon     9
# Wed     9
# Thu     8
# Sat     8
# Sun     7
# Name: dayofweek, dtype: int64

# %%
data['venue'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Pie Chart

# %%
data['dayofweek'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <AxesSubplot: ylabel='dayofweek'>

# %%
counts, bin_edges=np.histogram(data['match'], bins=60)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

# %%
data.loc[(data['age']>=43) & (data['age']<=45),['age']].value_counts()
# Out:
# age
# 43.0    3
# 45.0    3
# dtype: int64

# %% [markdown]
# # NUMERICAL DATA
#
# ## HISTOGRAMS

# %%
d=data['age'].values
plt.hist(d)
# Out:
# (array([21.,  3., 10.,  5.,  6.,  4.,  0.,  0.,  5.,  6.]),
#  array([20. , 22.5, 25. , 27.5, 30. , 32.5, 35. , 37.5, 40. , 42.5, 45. ]),
#  <BarContainer object of 10 artists>)

# %%
data.loc[(data['age']>=18) & (data['age']<=23),['age']].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Boxplots

# %%
sns.boxplot(data['age'])
# Out:
# <AxesSubplot: >

# %%
data['age'].median()
# Out:
# 26.0

# %% [markdown]
# # Kdeplot

# %%
sns.kdeplot(data['age'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %% [markdown]
# # Working with 2 variable/data  (Bivariate analysis)

# %% [markdown]
# ## 1. Categorical  vs  Numerical

# %% [markdown]
# ## a. Boxplot

# %%
data['age'].value_counts()
# Out:
# 20.0    7
# 21.0    7
# 22.0    7
# 25.0    5
# 41.0    4
# 26.0    4
# 28.0    4
# 32.0    3
# 34.0    3
# 43.0    3
# 45.0    3
# 24.0    3
# 30.0    2
# 27.0    1
# 29.0    1
# 31.0    1
# 33.0    1
# 40.0    1
# Name: age, dtype: int64

# %%
len(data.columns)
# Out:
# 54

# %% [markdown]
# # Bi-Variate Analysis

# %% [markdown]
# # 1. Categorical vs numerical

# %%
data['age'].value_counts()
# Out:
# 20.0    7
# 21.0    7
# 22.0    7
# 25.0    5
# 41.0    4
# 26.0    4
# 28.0    4
# 32.0    3
# 34.0    3
# 43.0    3
# 45.0    3
# 24.0    3
# 30.0    2
# 27.0    1
# 29.0    1
# 31.0    1
# 33.0    1
# 40.0    1
# Name: age, dtype: int64

# %%
data['dayofweek'].value_counts()
# Out:
# Tue    11
# Fri    10
# Mon     9
# Wed     9
# Thu     8
# Sat     8
# Sun     7
# Name: dayofweek, dtype: int64

# %%
sns.boxplot(x='dayofweek',y='age',data=data)
# Out:
# <AxesSubplot: xlabel='dayofweek', ylabel='age'>

# %%
sns.barplot(x='dayofweek',y='age',data=data)
# Out:
# <AxesSubplot: xlabel='dayofweek', ylabel='age'>

# %% [markdown]
# # 2. Numerical vs Numerical

# %%
m=data['age'].values
n=data['match'].values
plt.scatter(m,n)

# %% [markdown]
# # 3. Categorical vs Categorical

# %%
pd.crosstab(data['venue'],data['dayofweek']).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='venue'>
