# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv('FuelConsumption.csv')
data = data[['FUELCONSUMPTION_COMB_MPG','CO2EMISSIONS']]
data.rename(columns={'FUELCONSUMPTION_COMB_MPG':'comubtion','CO2EMISSIONS':'emission'},inplace=True)
data
# Out:
#       comubtion  emission
# 0            33       196
# 1            29       221
# 2            48       136
# 3            25       255
# 4            27       244
# ...         ...       ...
# 1062         24       271
# 1063         25       264
# 1064         24       271
# 1065         25       260
# 1066         22       294
#
# [1067 rows x 2 columns]

# %%
data.shape
# Out:
# (1067, 2)

# %%
plt.xlabel('comubtion')
plt.ylabel('emission')
plt.scatter(data.comubtion, data.emission, color='red', marker='.')

# %%
model = linear_model.LinearRegression()
model.fit(data.drop('emission', axis='columns'), data.emission)
# Out:
# LinearRegression()

# %%
model.predict([[18]])
# Out:
# D:\jupyter\mynumpy\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([321.14998401])

# %%
plt.plot(X_test,modell.predict(X_test),label="Modal")
plt.scatter(X_train,y_train,label="data", color="r")
plt.legend()
plt.show()

# %%
data.head(60)
# Out:
#     comubtion  emission
# 0          33       196
# 1          29       221
# 2          48       136
# 3          25       255
# 4          27       244
# 5          28       230
# 6          28       232
# 7          25       255
# 8          24       267
# 9          31       212
# 10         29       225
# 11         27       239
# 12         18       359
# 13         18       359
# 14         19       338
# 15         18       354
# 16         19       338
# 17         18       354
# 18         18       359
# 19         32       202
# 20         28       230
# 21         30       214
# 22         28       230
# 23         28       230
# 24         30       214
# 25         28       235
# 26         26       251
# 27         34       224
# 28         25       258
# 29         34       224
# 30         25       258
# 31         25       260
# 32         34       227
# 33         25       258
# 34         23       288
# 35         18       361
# 36         33       230
# ...

# %%
X=data.iloc[:,0:1].values
y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
modell = linear_model.LinearRegression()
modell.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=modell.predict(X_test)
# Out:
# array([322.37298476, 219.90243448, 243.54948455, 219.90243448,
#        156.84363431, 290.84358468, 219.90243448, 275.07888463,
#        212.02008446, 314.49063474, 298.7259347 , 346.02003483,
#        196.25538441, 282.96123465, 172.60833435, 267.19653461,
#        338.13768481, 235.66713452, 259.31418459, 322.37298476,
#        196.25538441, 196.25538441, 251.43183457, 251.43183457,
#         70.13778407, 282.96123465, 275.07888463, 346.02003483,
#        259.31418459,  -0.80336613, 322.37298476, 251.43183457,
#        306.60828472, 251.43183457, 196.25538441, 204.13773444,
#        290.84358468, 235.66713452, 251.43183457, 251.43183457,
#        188.37303439, 188.37303439, 212.02008446, 156.84363431,
#        290.84358468, 204.13773444, 267.19653461, 180.49068437,
#        361.78473487, 322.37298476, 314.49063474, 338.13768481,
#        290.84358468,  70.13778407, 243.54948455, 180.49068437,
#        282.96123465, 141.07893426, 267.19653461, 219.90243448,
# ...
